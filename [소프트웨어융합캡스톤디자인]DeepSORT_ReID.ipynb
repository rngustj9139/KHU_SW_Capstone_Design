# %%
# Data labeling 문제?
# Video에서 벗어나는 Object가 없어야하는 문제? ****
# ReID -> ID당 이미지 개수 및 총 instance 개수(ids) 문제? ****

# %%
# 파이썬 버전 출력

import sys

print(sys.version)
# Out:
# 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]

# %%
# 아래 세션 다시 시작 버튼 클릭 필요

# !pip install numpy==1.22.0
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 57.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.25.2
#     Uninstalling numpy-1.25.2:
#       Successfully uninstalled numpy-1.25.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# chex 0.1.86 requires numpy>=1.24.1, but you have numpy 1.22.0 which is incompatible.
# librosa 0.10.1 requires numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3, but you have numpy 1.22.0 which is incompatible.
# pandas-stubs 2.0.3.230814 requires numpy>=1.25.0; python_version >= "3.9", but you have numpy 1.22.0 which is incompatible.
# plotnine 0.12.4 requires numpy>=1.23.0, but you have numpy 1.22.0 which is incompatible.
# pywavelets 1.6.0 requires numpy<3,>=1.22.4, but you have numpy 1.22.0 which is incompatible.
# ...

# %%
import numpy as np
import sys

print(np.__version__)
# Out:
# 1.22.0

# %%
#코랩의 pytorch 버전이 2.0으로 upgrade됨.
import torch
print(torch.__version__)
# Out:
# 2.2.1+cu121

# %%
#1분 소모
# 하단 세션 다시 시작 버튼 클릭 필요

#현재 mmdetection이 pytorch 2.x를 지원하지 않음. pytorch 1.13+ CUDA 116 환경으로 코랩 커널 downgrade
# downgrade 설치시 ERROR: pip's dependency resolver... 부분은 신경쓰지 않아도 됨.
# !pip install torch==1.13.0+cu116 torchvision==0.14.0+cu116 --extra-index-url https://download.pytorch.org/whl/cu116
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu116
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 GB 1.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.2/24.2 MB 60.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 2.2.1+cu121
#     Uninstalling torch-2.2.1+cu121:
#       Successfully uninstalled torch-2.2.1+cu121
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.17.1+cu121
#     Uninstalling torchvision-0.17.1+cu121:
#       Successfully uninstalled torchvision-0.17.1+cu121
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.2.1+cu121 requires torch==2.2.1, but you have torch 1.13.0+cu116 which is incompatible.
# torchdata 0.7.1 requires torch>=2, but you have torch 1.13.0+cu116 which is incompatible.
# ...

# %%
#코랩의 pytorch 버전이 2.0으로 upgrade됨.
import torch
print(torch.__version__)
# Out:
# 1.13.0+cu116

# %%
# mmcv를 위해서 mmcv-full을 먼저 설치해야 함. https://mmcv.readthedocs.io/en/latest/get_started/installation.html 설치 과정 참조.
# !pip install mmcv-full -f https://download.openmmlab.com/mmcv/dist/cu116/torch1.13/index.html
# Out:
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu116/torch1.13/index.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.2/69.2 MB 20.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.7/254.7 kB 6.0 MB/s eta 0:00:00
# ...

# %%
# 2023년 4월 6일 기준으로 mmdetection이 3.0으로 upgrade됨. 실습 코드는 mmdetection 2.x 기준임.
# mmdetection 2.x branch의 소스코드 기반으로 mmdetection 설치 필요.
# !git clone --branch 2.x https://github.com/open-mmlab/mmdetection.git
# !cd mmdetection; python setup.py install
# Out:
# Cloning into 'mmdetection'...
# remote: Enumerating objects: 38019, done.
# remote: Counting objects: 100% (102/102), done.
# remote: Compressing objects: 100% (75/75), done.
# remote: Total 38019 (delta 39), reused 60 (delta 25), pack-reused 37917
# Receiving objects: 100% (38019/38019), 63.24 MiB | 25.50 MiB/s, done.
# Resolving deltas: 100% (26201/26201), done.
# running install
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
# ...

# %%
# 아래를 수행하기 전에 kernel을 restart 해야 함(런타임 다시시작 -> 세션 다시시작)
from mmdet.apis import init_detector, inference_detector
import mmcv
# Out:
# /usr/local/lib/python3.10/dist-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(

# %%
# Check nvcc version
# !nvcc -V
# Check GCC version
# !gcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Tue_Aug_15_22:02:13_PDT_2023
# Cuda compilation tools, release 12.2, V12.2.140
# Build cuda_12.2.r12.2/compiler.33191640_0
# gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
# Copyright (C) 2021 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# !pwd
# Out:
# /content

# %%
# clone the MMTracking repository
# !git clone https://github.com/open-mmlab/mmtracking.git

# %cd mmtracking
# Out:
# Cloning into 'mmtracking'...
# remote: Enumerating objects: 7927, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 7927 (delta 0), reused 4 (delta 0), pack-reused 7915
# Receiving objects: 100% (7927/7927), 2.92 MiB | 27.45 MiB/s, done.
# Resolving deltas: 100% (5017/5017), done.
# /content/mmtracking

# %%
# !pwd
# Out:
# /content/mmtracking

# %%
# 1분 소모
# 설치시 ERROR: pip's dependency resolver... 부분은 신경쓰지 않아도 됨.
# install MMTracking and its dependencies
# !pip install -r requirements/build.txt
# !pip install -e .
# used to MOT evaluation
# !pip install git+https://github.com/JonathonLuiten/TrackEval.git
# Out:
# ...
# Obtaining file:///content/mmtracking
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 39.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 648.8/648.8 kB 38.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.5/161.5 kB 21.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 49.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 41.7 MB/s eta 0:00:00
# ...
#   Created wheel for attributee: filename=attributee-0.1.8-py3-none-any.whl size=12860 sha256=0ec74d82a83f747c633a658580c228611334365f368fb202b3cc70a928489e5d
#   Stored in directory: /root/.cache/pip/wheels/0a/e2/ab/3292c3de25a615d3ef2011d65e68f103c025d82149ac6c2f14
# ...

# %%
from mmcv import collect_env
collect_env() # 설정된 환경 확인
# Out:
# {'sys.platform': 'linux',
#  'Python': '3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]',
#  'CUDA available': True,
#  'GPU 0': 'Tesla V100-SXM2-16GB',
#  'CUDA_HOME': '/usr/local/cuda',
#  'NVCC': 'Cuda compilation tools, release 12.2, V12.2.140',
#  'GCC': 'x86_64-linux-gnu-gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0',
#  'PyTorch': '1.13.0+cu116',
# ...

# %%
# Check Pytorch installation
import torch, torchvision
print(torch.__version__, torch.cuda.is_available())
# Out:
# 1.13.0+cu116 True

# %%
# Check mmcv installation
from mmcv.ops import get_compiling_cuda_version, get_compiler_version
print(get_compiling_cuda_version())
print(get_compiler_version())
# Out:
# 11.6
# GCC 9.3

# %%
# Check MMDetection installation
import mmdet
print(mmdet.__version__)
# Out:
# 2.28.2

# %%
# Check MMTracking installation
import mmtrack
print(mmtrack.__version__)
# Out:
# 0.14.0

# %%
import tempfile

print(tempfile.TemporaryDirectory())
# Out:
# <TemporaryDirectory '/tmp/tmpz1hlsa8c'>

# %%
print(tempfile.TemporaryDirectory().name)
# Out:
# /tmp/tmpivulz0r7

# %%
# !pwd
# Out:
# /content/mmtracking

# %%
# !mkdir /content/mmtracking/data/

# %%
# !mkdir /content/mmtracking/data/MOT17_tiny/

# %%
# !mkdir /content/mmtracking/data/MOT17_tiny/train/

# %%
# !mkdir /content/mmtracking/data/MOT17_tiny/test/

# %%
# !mkdir /content/mmtracking/data/MOT17_tiny/train/MOT17-04-FRCNN/

# %%
# !mkdir /content/mmtracking/data/MOT17_tiny/train/MOT17-04-FRCNN/det

# %%
# !mkdir /content/mmtracking/data/MOT17_tiny/train/MOT17-04-FRCNN/gt

# %%
# 1분 소모

# !unzip -qq '/content/drive/Othercomputers/내 노트북/google_drive/DeepSORT_ReID_input/img1.zip' -d '/content/mmtracking/data/MOT17_tiny/train/MOT17-04-FRCNN'

# %%
# !mkdir /content/mmtracking/data/MOT17_tiny/train/MOT17-04-FRCNN/img1

# %%
import shutil
import os

tracking_img_file_list = os.listdir("/content/mmtracking/data/MOT17_tiny/train/MOT17-04-FRCNN/content/data")

for tracking_img_file in tracking_img_file_list:
  filename = tracking_img_file
  src = "/content/mmtracking/data/MOT17_tiny/train/MOT17-04-FRCNN/content/data"
  dst = "/content/mmtracking/data/MOT17_tiny/train/MOT17-04-FRCNN/img1"

  shutil.move(os.path.join(src, filename), os.path.join(dst, filename))

# %%
# 0.PNG부터 174.PNG까지 총 175개의 이미지 파일 존재

tracking_img_file_list = os.listdir("/content/mmtracking/data/MOT17_tiny/train/MOT17-04-FRCNN/img1")
len(tracking_img_file_list)
# Out:
# 175

# %%
os.rmdir('/content/mmtracking/data/MOT17_tiny/train/MOT17-04-FRCNN/content/data')
os.rmdir('/content/mmtracking/data/MOT17_tiny/train/MOT17-04-FRCNN/content')

# %%
# 이미지 파일명 변경

import os

# 주어진 디렉토리에 있는 항목들의 이름을 담고 있는 리스트를 반환
# 리스트는 임의의 순서대로 나열 됨

file_path = '/content/mmtracking/data/MOT17_tiny/train/MOT17-04-FRCNN/img1'
file_names = os.listdir(file_path)
file_names
# Out:
# ['125.PNG',
#  '77.PNG',
#  '146.PNG',
#  '150.PNG',
#  '109.PNG',
#  '127.PNG',
#  '0.PNG',
#  '107.PNG',
#  '56.PNG',
#  '67.PNG',
#  '124.PNG',
#  '112.PNG',
#  '121.PNG',
#  '37.PNG',
#  '143.PNG',
#  '14.PNG',
#  '88.PNG',
#  '95.PNG',
#  '69.PNG',
#  '19.PNG',
#  '114.PNG',
#  '25.PNG',
#  '92.PNG',
#  '160.PNG',
#  '174.PNG',
#  '24.PNG',
#  '129.PNG',
#  '35.PNG',
#  '2.PNG',
#  '87.PNG',
#  '142.PNG',
#  '46.PNG',
#  '45.PNG',
#  '73.PNG',
#  '17.PNG',
#  '103.PNG',
#  '115.PNG',
#  '84.PNG',
#  '21.PNG',
#  '41.PNG',
#  '167.PNG',
#  '26.PNG',
#  '12.PNG',
#  '162.PNG',
#  '105.PNG',
#  '168.PNG',
#  '152.PNG',
#  '47.PNG',
#  '38.PNG',
#  '99.PNG',
#  '63.PNG',
#  '156.PNG',
#  '10.PNG',
#  '170.PNG',
#  '48.PNG',
#  '53.PNG',
#  '34.PNG',
#  '79.PNG',
#  '100.PNG',
#  '3.PNG',
#  '76.PNG',
#  '40.PNG',
#  '135.PNG',
#  '110.PNG',
#  '61.PNG',
#  '71.PNG',
#  '11.PNG',
#  '20.PNG',
#  '18.PNG',
#  '139.PNG',
#  '31.PNG',
#  '122.PNG',
#  '78.PNG',
#  '151.PNG',
# ...

# %%
# 이미지 파일명 변경

for name in file_names:
  src = os.path.join(file_path, name)

  tmp = name.split('.')[0]

  if (len(str(int(tmp) + 1)) == 1):
    name = '00000' + (str(int(tmp) + 1)) + ".PNG"
  elif (len(str(int(tmp) + 1)) == 2):
    name = '0000' + (str(int(tmp) + 1)) + ".PNG"
  elif (len(str(int(tmp) + 1)) == 3):
    name = '000' + (str(int(tmp) + 1)) + ".PNG"

  dst = os.path.join(file_path, name)

  os.rename(src, dst)

# %%
gt_file_name = "gt.txt"

src = "/content/drive/Othercomputers/내 노트북/google_drive/DeepSORT_ReID_input"
dst = "/content/mmtracking/data/MOT17_tiny/train/MOT17-04-FRCNN/gt"

shutil.copy(os.path.join(src, gt_file_name), os.path.join(dst, gt_file_name))
# Out:
# '/content/mmtracking/data/MOT17_tiny/train/MOT17-04-FRCNN/gt/gt.txt'

# %%
# # # gt.txt의 bbox 좌표 변환 (소숫점 3자리를 초과하면 clip 수행) & Confidence 변환 (1 -> 0)

# edited_lines = []

# with open("/content/mmtracking/data/MOT17_tiny/train/MOT17-04-FRCNN/gt/gt.txt") as f:
#     lines = f.readlines()
#     for line in lines:
#       print(f"previous line: {line}")
#       # 조건에 따라 원하는 대로 line을 수정
#       tmp = line.split(",")
#       print(f"previous splited line: {tmp}")

#       tmp[2] = tmp[2].split(".")[0]
#       tmp[3] = tmp[3].split(".")[0]
#       tmp[4] = tmp[4].split(".")[0]
#       tmp[5] = tmp[5].split(".")[0]

#       tmp[6] = str(0)

#       tmp[8] = "1\n"

#       tmp = ",".join(tmp)
#       print(f"new joined line: {tmp}")
#       edited_lines.append(tmp)

# with open("/content/mmtracking/data/MOT17_tiny/train/MOT17-04-FRCNN/gt/gt.txt", 'w') as f:
#     f.writelines(edited_lines)

# %%
seq_file_name = "seqinfo.ini"

src = "/content/drive/Othercomputers/내 노트북/google_drive/DeepSORT_ReID_input"
dst = "/content/mmtracking/data/MOT17_tiny/train/MOT17-04-FRCNN"

shutil.copy(os.path.join(src, seq_file_name), os.path.join(dst, seq_file_name))
# Out:
# '/content/mmtracking/data/MOT17_tiny/train/MOT17-04-FRCNN/seqinfo.ini'

# %%
import cv2

img = cv2.imread("/content/mmtracking/data/MOT17_tiny/train/MOT17-04-FRCNN/img1/000167.PNG")
img.shape
# Out:
# (1080, 1920, 3)

# %%
# /content/mmtracking/data/MOT17_tiny/train/MOT17-04-FRCNN/seqinfo.ini

'''

[Sequence]
name=MOT17-04-FRCNN
imDir=img1
frameRate=35
seqLength=175
imWidth=1920
imHeight=1080
imExt=.PNG

'''

# %%
# gt.txt 파일을 기반으로 det.txt 파일 생성
# det.txt -> imageFileNumber(FrameNumber), id(존재하지 않으므로 모두 -1값을 가짐), BBoxTop, BBoxLeft, BBoxWidth, BBoxHeight, Confidence Score

edited_lines = []

with open("/content/mmtracking/data/MOT17_tiny/train/MOT17-04-FRCNN/gt/gt.txt") as f:
    lines = f.readlines()
    for line in lines:
        # 조건에 따라 원하는 대로 line을 수정
        tmp = line.split(",")
        edited_lines.append(str(tmp[0]) + "," + "-1" + "," + str(tmp[3]) + "," + str(tmp[2]) + "," + str(tmp[4]) + "," + str(tmp[5]) + "," + "1" + "\n")

with open("/content/mmtracking/data/MOT17_tiny/train/MOT17-04-FRCNN/det/det.txt", 'w') as f:
    f.writelines(edited_lines)

# %%
# 42초 소모 (Tutorial datasets download)

# !mkdir data
# !wget https://download.openmmlab.com/mmtracking/data/MOT17_tiny.zip -P ./data
# !unzip -q ./data/MOT17_tiny.zip -d ./data

# %%
'''
gt.txt.는 9가지 속성 존재
gt.txt => Frame number, ID number, BBox left, BBox top, BBox width, BBox height, Confidence Score, Class, Visibility(가시성)


================================================================================================================================================


det.txt는 7개의 속성 존재(/det/det.txt 파일은 Re-identification을 위한 Annotation은 제외된채로 Detection만을 위한 Annotation이 되어 있다)
det.txt => imageFileNumber(FrameNumber), id(존재하지 않으므로 모두 -1값을 가짐), BBoxTop, BBoxLeft, BBoxWidth, BBoxHeight, Confidence Score
'''

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 1분 소모

# convert the dataset to coco format (Detection을 위한 annotation 구축)
# !python ./tools/convert_datasets/mot/mot2coco.py -i ./data/MOT17_tiny/ -o ./data/MOT17_tiny/annotations --split-train --convert-det

'''
Person Re-Identification: 복수의 다양한 각도 시점에서 찍은 사진에서 동일 인물을 찾기
'''
# crop pedestrian patches from the original dataset for training reid model. It may take a few minutes (ReID를 위한 파일 구축)
# !rm -rf ./data/MOT17_tiny/reid
# !python ./tools/convert_datasets/mot/mot2reid.py -i ./data/MOT17_tiny/ -o ./data/MOT17_tiny/reid --val-split 0.9 --vis-threshold 0.8
# Out:
# /usr/local/lib/python3.10/dist-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# Converting train set to COCO format
# 100% 1/1 [00:00<00:00, 75.68it/s]
# train has 8 instances.
# Done! Saved as ./data/MOT17_tiny/annotations/train_cocoformat.json and ./data/MOT17_tiny/annotations/train_detections.pkl
# Converting test set to COCO format
# 0it [00:00, ?it/s]
# test has 0 instances.
# Done! Saved as ./data/MOT17_tiny/annotations/test_cocoformat.json and ./data/MOT17_tiny/annotations/test_detections.pkl
# Converting half-train set to COCO format
# 100% 1/1 [00:00<00:00, 61.55it/s]
# half-train has 8 instances.
# ...

# %%
# /content/mmtracking/configs/det/faster-rcnn_r50_fpn_4e_mot17-half.py

'''

USE_MMDET = True
_base_ = [
    '../_base_/models/faster_rcnn_r50_fpn.py',
    '../_base_/datasets/coco_detection.py', '../_base_/default_runtime.py'
]
model = dict(
    detector=dict(
        rpn_head=dict(bbox_coder=dict(clip_border=False)),
        roi_head=dict(
            bbox_head=dict(bbox_coder=dict(clip_border=False), num_classes=1)),
        init_cfg=dict(
            type='Pretrained',
            checkpoint=  # noqa: E251
            '/content/drive/Othercomputers/내 노트북/google_drive/traffic_model_result/epoch_15.pth'  # noqa: E501
        )))
# learning policy
lr_config = dict(
    policy='step',
    warmup='linear',
    warmup_iters=100,
    warmup_ratio=1.0 / 100,
    step=[3])
# runtime settings
total_epochs = 15

'''

# %%
# /content/mmtracking/configs/_base_/datasets/coco_detection.py

'''

dataset_type = 'CocoDataset'
data_root = 'data/MOT17_tiny/'
img_norm_cfg = dict(
    mean=[123.675, 116.28, 103.53], std=[58.395, 57.12, 57.375], to_rgb=True)
train_pipeline = [
    dict(type='LoadImageFromFile'),
    dict(type='LoadAnnotations', with_bbox=True),
    dict(type='Resize', img_scale=(1333, 800), keep_ratio=True),
    dict(type='RandomFlip', flip_ratio=0.5),
    dict(type='Normalize', **img_norm_cfg),
    dict(type='Pad', size_divisor=32),
    dict(type='DefaultFormatBundle'),
    dict(type='Collect', keys=['img', 'gt_bboxes', 'gt_labels']),
]
test_pipeline = [
    dict(type='LoadImageFromFile'),
    dict(
        type='MultiScaleFlipAug',
        img_scale=(1333, 800),
        flip=False,
        transforms=[
            dict(type='Resize', keep_ratio=True),
            dict(type='RandomFlip'),
            dict(type='Normalize', **img_norm_cfg),
            dict(type='Pad', size_divisor=32),
            dict(type='ImageToTensor', keys=['img']),
            dict(type='Collect', keys=['img']),
        ])
]
data = dict(
    samples_per_gpu=2,
    workers_per_gpu=2,
    train=dict(
      type=dataset_type,
      ann_file=data_root + 'annotations/train_cocoformat.json',
      img_prefix=data_root + 'train',
      classes=('pedestrian', ),
      pipeline=train_pipeline),
    val=dict(
      type=dataset_type,
      ann_file=data_root + 'annotations/half-val_cocoformat.json',
      img_prefix=data_root + 'train',
      classes=('pedestrian', ),
      pipeline=test_pipeline),
    test=dict(
      type=dataset_type,
      ann_file=data_root + 'annotations/half-val_cocoformat.json',
      img_prefix=data_root + 'train',
      classes=('pedestrian', ),
      pipeline=test_pipeline))
evaluation = dict(interval=1, metric='bbox')

'''

# %%
# !nvidia-smi # 할당된 GPU 확인
# Out:
# Wed Apr 17 06:00:00 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla V100-SXM2-16GB           Off | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0              23W / 300W |      2MiB / 16384MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %% [markdown]
# # Train Detector model for multi object tracking (DeepSORT)

# %%
import mmcv
from mmdet.apis import set_random_seed

cfg = mmcv.Config.fromfile('./configs/det/faster-rcnn_r50_fpn_4e_mot17-half.py') # 4e는 최대 4번의 epoch를 수행한다는 의미
cfg.model.detector.init_cfg.checkpoint = '/content/drive/Othercomputers/내 노트북/google_drive/traffic_model_result/epoch_15.pth'

cfg.work_dir = '/content/drive/Othercomputers/내 노트북/google_drive/DeepSORT_ReID_result'
cfg.seed = 0
set_random_seed(0, deterministic=False)

cfg.log_config.interval = 10
# 1번 마다 한번씩 로그를 작성(학습시 cell에 출력 됨, None.log.json에도 저장됨)
cfg.log_config.max_epochs = 1

cfg.gpu_ids = range(1)
cfg.device='cuda'

print(cfg)
# Out:
# Config (path: ./configs/det/faster-rcnn_r50_fpn_4e_mot17-half.py): {'model': {'detector': {'type': 'FasterRCNN', 'backbone': {'type': 'ResNet', 'depth': 50, 'num_stages': 4, 'out_indices': (0, 1, 2, 3), 'frozen_stages': 1, 'norm_cfg': {'type': 'BN', 'requires_grad': True}, 'norm_eval': True, 'style': 'pytorch', 'init_cfg': {'type': 'Pretrained', 'checkpoint': 'torchvision://resnet50'}}, 'neck': {'type': 'FPN', 'in_channels': [256, 512, 1024, 2048], 'out_channels': 256, 'num_outs': 5}, 'rpn_head': {'type': 'RPNHead', 'in_channels': 256, 'feat_channels': 256, 'anchor_generator': {'type': 'AnchorGenerator', 'scales': [8], 'ratios': [0.5, 1.0, 2.0], 'strides': [4, 8, 16, 32, 64]}, 'bbox_coder': {'type': 'DeltaXYWHBBoxCoder', 'target_means': [0.0, 0.0, 0.0, 0.0], 'target_stds': [1.0, 1.0, 1.0, 1.0], 'clip_border': False}, 'loss_cls': {'type': 'CrossEntropyLoss', 'use_sigmoid': True, 'loss_weight': 1.0}, 'loss_bbox': {'type': 'SmoothL1Loss', 'beta': 0.1111111111111111, 'loss_weight': 1.0}}
# ...

# %%
cfg.model.detector.init_cfg.checkpoint
# Out:
# '/content/drive/Othercomputers/내 노트북/google_drive/traffic_model_result/epoch_15.pth'

# %%
import os.path as osp

from mmtrack.datasets import build_dataset
from mmdet.apis import train_detector as train_model
from mmdet.models import build_detector as build_model

mmcv.mkdir_or_exist(osp.abspath(cfg.work_dir))

model = build_model(cfg.model.detector)
# model.init_weights()
datasets = [build_dataset(cfg.data.train)]
# Out:
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!

# %%
# 1400 count

datasets
# Out:
# [
#  CocoDataset Train dataset with number of images 175, and instance counts:
#  +----------------+-------+----------+-------+----------+-------+----------+-------+----------+-------+
#  | category       | count | category | count | category | count | category | count | category | count |
#  +----------------+-------+----------+-------+----------+-------+----------+-------+----------+-------+
#  |                |       |          |       |          |       |          |       |          |       |
#  | 0 [pedestrian] | 1400  |          |       |          |       |          |       |          |       |
#  +----------------+-------+----------+-------+----------+-------+----------+-------+----------+-------+]

# %%
# epoch:15회 => 6분 소모
# samples_per_gpu는 default 2의 값을 가지므로 batch size는 gpu개수(1) * samples_per_gpu(2) == 2가 된다. 즉 약 175장의 학습 데이터 이미지를 2개의 Batch(각각 약 87장)로 나눠서 학습을 수행

train_model(model, datasets, cfg)
# Out:
# /usr/local/lib/python3.10/dist-packages/mmdet-2.28.2-py3.10.egg/mmdet/utils/compat_config.py:28: UserWarning: config is now expected to have a `runner` section, please set `runner` in your config.
#   warnings.warn(
# 2024-04-16 13:34:23,519 - mmdet - INFO - Automatic scaling of learning rate (LR) has been disabled.
# 2024-04-16 13:34:23,524 - mmdet - INFO - Start running, host: root@f668adc752f2, work_dir: /content/drive/Othercomputers/내 노트북/google_drive/DeepSORT_ReID_result
# 2024-04-16 13:34:23,527 - mmdet - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) StepLrUpdaterHook
# (NORMAL      ) CheckpointHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) StepLrUpdaterHook
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) StepLrUpdaterHook
# (LOW         ) IterTimerHook
#  --------------------
# after_train_iter:
# ...

# %% [markdown]
# # Train ReID model for multi object tracking (DeepSORT)

# %%
# /content/mmtracking/configs/_base_/datasets/mot_challenge_reid.py

'''

dataset_type = 'ReIDDataset'
img_norm_cfg = dict(
    mean=[123.675, 116.28, 103.53], std=[58.395, 57.12, 57.375], to_rgb=True)
train_pipeline = [
    dict(type='LoadMultiImagesFromFile', to_float32=True),
    dict(
        type='SeqResize',
        img_scale=(128, 256),
        share_params=False,
        keep_ratio=False,
        bbox_clip_border=False,
        override=False),
    dict(
        type='SeqRandomFlip',
        share_params=False,
        flip_ratio=0.5,
        direction='horizontal'),
    dict(type='SeqNormalize', **img_norm_cfg),
    dict(type='VideoCollect', keys=['img', 'gt_label']),
    dict(type='ReIDFormatBundle')
]
test_pipeline = [
    dict(type='LoadImageFromFile'),
    dict(type='Resize', img_scale=(128, 256), keep_ratio=False),
    dict(type='Normalize', **img_norm_cfg),
    dict(type='ImageToTensor', keys=['img']),
    dict(type='Collect', keys=['img'], meta_keys=[])
]
data_root = 'data/MOT17_tiny/'
data = dict(
    samples_per_gpu=1,
    workers_per_gpu=2,
    train=dict(
        type=dataset_type,
        triplet_sampler=dict(num_ids=8, ins_per_id=4),
        data_prefix=data_root + 'reid/imgs',
        ann_file=data_root + 'reid/meta/train.txt',
        pipeline=train_pipeline),
    val=dict(
        type=dataset_type,
        triplet_sampler=None,
        data_prefix=data_root + 'reid/imgs',
        ann_file=data_root + 'reid/meta/val_90.txt',
        pipeline=test_pipeline),
    test=dict(
        type=dataset_type,
        triplet_sampler=None,
        data_prefix=data_root + 'reid/imgs',
        ann_file=data_root + 'reid/meta/val_90.txt',
        pipeline=test_pipeline))
evaluation = dict(interval=1, metric='mAP')

'''

# %%
import mmcv
from mmdet.apis import set_random_seed

cfg = mmcv.Config.fromfile('./configs/reid/resnet50_b32x8_MOT17.py')

# learning policy
cfg.lr_config = dict(
    policy='step',
    warmup='linear',
    warmup_iters=200,
    warmup_ratio=1.0 / 200,
    step=[1])
cfg.total_epochs = 5

# /content/mmtracking/data/MOT17_tiny/reid/imgs
cfg.data.train.triplet_sampler["num_ids"] = 8 # 한 프레임(이미지)당 나타나는 고유한 객체의 수를 의미(각 고유한 객체는 고유한 id를 가진다) -> 8

# /content/mmtracking/data/MOT17_tiny/reid/imgs/MOT17-04-FRCNN_000001
cfg.data.train.triplet_sampler["ins_per_id"] = 3 # 한 id당 이미지의 개수

cfg.work_dir = '/content/drive/Othercomputers/내 노트북/google_drive/DeepSORT_ReID_result/only_ReID'
cfg.seed = 0
set_random_seed(0, deterministic=False)
cfg.gpu_ids = range(1)
cfg.device='cuda'
print(cfg)
# Out:
# Config (path: ./configs/reid/resnet50_b32x8_MOT17.py): {'dataset_type': 'ReIDDataset', 'img_norm_cfg': {'mean': [123.675, 116.28, 103.53], 'std': [58.395, 57.12, 57.375], 'to_rgb': True}, 'train_pipeline': [{'type': 'LoadMultiImagesFromFile', 'to_float32': True}, {'type': 'SeqResize', 'img_scale': (128, 256), 'share_params': False, 'keep_ratio': False, 'bbox_clip_border': False, 'override': False}, {'type': 'SeqRandomFlip', 'share_params': False, 'flip_ratio': 0.5, 'direction': 'horizontal'}, {'type': 'SeqNormalize', 'mean': [123.675, 116.28, 103.53], 'std': [58.395, 57.12, 57.375], 'to_rgb': True}, {'type': 'VideoCollect', 'keys': ['img', 'gt_label']}, {'type': 'ReIDFormatBundle'}], 'test_pipeline': [{'type': 'LoadImageFromFile'}, {'type': 'Resize', 'img_scale': (128, 256), 'keep_ratio': False}, {'type': 'Normalize', 'mean': [123.675, 116.28, 103.53], 'std': [58.395, 57.12, 57.375], 'to_rgb': True}, {'type': 'ImageToTensor', 'keys': ['img']}, {'type': 'Collect', 'keys': ['img'], 'me
# ...

# %%
from mmtrack.datasets import build_dataset
from mmdet.apis import train_detector as train_model
from mmtrack.models import build_reid as build_model

model = build_model(cfg.model.reid)
model.init_weights()
datasets = [build_dataset(cfg.data.train)]
datasets[0].CLASSES = ("pedestrian", )
model.CLASSES = datasets[0].CLASSES
# Out:
# 2024-04-17 06:00:35,938 - mmcv - INFO - initialize BaseReID with init_cfg {'type': 'Pretrained', 'checkpoint': 'https://download.openmmlab.com/mmclassification/v0/resnet/resnet50_batch256_imagenet_20200708-cfb998bf.pth'}
# 2024-04-17 06:00:35,940 - mmcv - INFO - load model from: https://download.openmmlab.com/mmclassification/v0/resnet/resnet50_batch256_imagenet_20200708-cfb998bf.pth
# 2024-04-17 06:00:35,942 - mmcv - INFO - load checkpoint from http path: https://download.openmmlab.com/mmclassification/v0/resnet/resnet50_batch256_imagenet_20200708-cfb998bf.pth
# Downloading: "https://download.openmmlab.com/mmclassification/v0/resnet/resnet50_batch256_imagenet_20200708-cfb998bf.pth" to /root/.cache/torch/hub/checkpoints/resnet50_batch256_imagenet_20200708-cfb998bf.pth
#   0%|          | 0.00/97.7M [00:00<?, ?B/s]
# 2024-04-17 06:00:37,507 - mmcv - WARNING - The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: head.fc.weight, head.fc.bias
#
# ...

# %%
datasets

# %%
datasets[0][0]
# Out:
# {'img': DataContainer(tensor([[[[ 0.9136,  0.9315,  0.9454,  ...,  0.7762,  0.7443,  0.7419],
#            [ 0.9106,  0.9315,  0.9454,  ...,  0.7762,  0.7443,  0.7419],
#            [ 0.9030,  0.9315,  0.9454,  ...,  0.7762,  0.7443,  0.7419],
#            ...,
#            [ 0.8119,  0.8001,  0.7822,  ...,  0.5374,  0.5642,  0.5661],
#            [ 0.8354,  0.8312,  0.8132,  ...,  0.5598,  0.5802,  0.5817],
#            [ 0.8447,  0.8435,  0.8255,  ...,  0.5687,  0.5866,  0.5878]],
#
#           [[ 0.8709,  0.8892,  0.9034,  ...,  0.6254,  0.6416,  0.6429],
#            [ 0.8678,  0.8892,  0.9034,  ...,  0.6254,  0.6416,  0.6429],
#            [ 0.8600,  0.8892,  0.9034,  ...,  0.6254,  0.6416,  0.6429],
#            ...,
#            [ 0.7669,  0.7549,  0.7365,  ...,  0.4863,  0.4648,  0.4631],
#            [ 0.7909,  0.7866,  0.7683,  ...,  0.5092,  0.4812,  0.4790],
#            [ 0.8004,  0.7992,  0.7809,  ...,  0.5183,  0.4878,  0.4853]],
#
# ...

# %%
print(cfg)
# Out:
# Config (path: ./configs/reid/resnet50_b32x8_MOT17.py): {'dataset_type': 'ReIDDataset', 'img_norm_cfg': {'mean': [123.675, 116.28, 103.53], 'std': [58.395, 57.12, 57.375], 'to_rgb': True}, 'train_pipeline': [{'type': 'LoadMultiImagesFromFile', 'to_float32': True}, {'type': 'SeqResize', 'img_scale': (128, 256), 'share_params': False, 'keep_ratio': False, 'bbox_clip_border': False, 'override': False}, {'type': 'SeqRandomFlip', 'share_params': False, 'flip_ratio': 0.5, 'direction': 'horizontal'}, {'type': 'SeqNormalize', 'mean': [123.675, 116.28, 103.53], 'std': [58.395, 57.12, 57.375], 'to_rgb': True}, {'type': 'VideoCollect', 'keys': ['img', 'gt_label']}, {'type': 'ReIDFormatBundle'}], 'test_pipeline': [{'type': 'LoadImageFromFile'}, {'type': 'Resize', 'img_scale': (128, 256), 'keep_ratio': False}, {'type': 'Normalize', 'mean': [123.675, 116.28, 103.53], 'std': [58.395, 57.12, 57.375], 'to_rgb': True}, {'type': 'ImageToTensor', 'keys': ['img']}, {'type': 'Collect', 'keys': ['img'], 'me
# ...

# %%
model.state_dict
# Out:
# <bound method Module.state_dict of BaseReID(
#   (backbone): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): ResLayer(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
cfg.data.train
# Out:
# {'type': 'ReIDDataset',
#  'triplet_sampler': {'num_ids': 8, 'ins_per_id': 3},
#  'data_prefix': 'data/MOT17_tiny/reid/imgs',
#  'ann_file': 'data/MOT17_tiny/reid/meta/train.txt',
#  'pipeline': [{'type': 'LoadMultiImagesFromFile', 'to_float32': True},
#   {'type': 'SeqResize',
#    'img_scale': (128, 256),
#    'share_params': False,
#    'keep_ratio': False,
#    'bbox_clip_border': False,
#    'override': False},
#   {'type': 'SeqRandomFlip',
#    'share_params': False,
#    'flip_ratio': 0.5,
#    'direction': 'horizontal'},
#   {'type': 'SeqNormalize',
#    'mean': [123.675, 116.28, 103.53],
#    'std': [58.395, 57.12, 57.375],
#    'to_rgb': True},
#   {'type': 'VideoCollect', 'keys': ['img', 'gt_label']},
#   {'type': 'ReIDFormatBundle'}]}

# %%
print(datasets[0].CLASSES)
# Out:
# ('pedestrian',)

# %%
print(model.CLASSES)
# Out:
# ('pedestrian',)

# %%
# epoch:5회 => 11분 소모

train_model(model, datasets, cfg)
# train_model(model, datasets, cfg, validate=False)
# Out:
# 2024-04-16 13:46:32,713 - mmdet - INFO - Automatic scaling of learning rate (LR) has been disabled.
# 2024-04-16 13:46:32,718 - mmdet - INFO - Start running, host: root@f668adc752f2, work_dir: /content/drive/Othercomputers/내 노트북/google_drive/DeepSORT_ReID_result/only_ReID
# 2024-04-16 13:46:32,719 - mmdet - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) StepLrUpdaterHook
# (NORMAL      ) CheckpointHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) StepLrUpdaterHook
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) StepLrUpdaterHook
# (LOW         ) IterTimerHook
#  --------------------
# after_train_iter:
# (ABOVE_NORMAL) OptimizerHook
# (NORMAL      ) CheckpointHook
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) CheckpointHook
# ...

# %% [markdown]
# # DeepSORT with ReID

# %%
# /content/mmtracking/configs/_base_/datasets/mot_challenge.py

'''

# dataset settings
dataset_type = 'MOTChallengeDataset'
img_norm_cfg = dict(
    mean=[123.675, 116.28, 103.53], std=[58.395, 57.12, 57.375], to_rgb=True)
train_pipeline = [
    dict(type='LoadMultiImagesFromFile', to_float32=True),
    dict(type='SeqLoadAnnotations', with_bbox=True, with_track=True),
    dict(
        type='SeqResize',
        img_scale=(1088, 1088),
        share_params=True,
        ratio_range=(0.8, 1.2),
        keep_ratio=True,
        bbox_clip_border=False),
    dict(type='SeqPhotoMetricDistortion', share_params=True),
    dict(
        type='SeqRandomCrop',
        share_params=False,
        crop_size=(1088, 1088),
        bbox_clip_border=False),
    dict(type='SeqRandomFlip', share_params=True, flip_ratio=0.5),
    dict(type='SeqNormalize', **img_norm_cfg),
    dict(type='SeqPad', size_divisor=32),
    dict(type='MatchInstances', skip_nomatch=True),
    dict(
        type='VideoCollect',
        keys=[
            'img', 'gt_bboxes', 'gt_labels', 'gt_match_indices',
            'gt_instance_ids'
        ]),
    dict(type='SeqDefaultFormatBundle', ref_prefix='ref')
]
test_pipeline = [
    dict(type='LoadImageFromFile'),
    dict(
        type='MultiScaleFlipAug',
        img_scale=(1088, 1088),
        flip=False,
        transforms=[
            dict(type='Resize', keep_ratio=True),
            dict(type='RandomFlip'),
            dict(type='Normalize', **img_norm_cfg),
            dict(type='Pad', size_divisor=32),
            dict(type='ImageToTensor', keys=['img']),
            dict(type='VideoCollect', keys=['img'])
        ])
]
data_root = 'data/MOT17_tiny/'
data = dict(
    samples_per_gpu=2,
    workers_per_gpu=2,
    train=dict(
        type=dataset_type,
        visibility_thr=-1,
        ann_file=data_root + 'annotations/train_cocoformat.json',
        img_prefix=data_root + 'train',
        ref_img_sampler=dict(
            num_ref_imgs=1,
            frame_range=10,
            filter_key_img=True,
            method='uniform'),
        classes=('pedestrian', ),
        pipeline=train_pipeline),
    val=dict(
        type=dataset_type,
        ann_file=data_root + 'annotations/half-val_cocoformat.json',
        img_prefix=data_root + 'train',
        ref_img_sampler=None,
        classes=('pedestrian', ),
        pipeline=test_pipeline),
    test=dict(
        type=dataset_type,
        ann_file=data_root + 'annotations/half-val_cocoformat.json',
        img_prefix=data_root + 'train',
        ref_img_sampler=None,
        classes=('pedestrian', ),
        pipeline=test_pipeline))

'''

# %%
# !pwd
# Out:
# /content/mmtracking

# %%
import mmcv
from mmdet.apis import set_random_seed

# /content/mmtracking/configs/mot/deepsort/deepsort_faster-rcnn_fpn_4e_mot17-private-half.py
cfg = mmcv.Config.fromfile('./configs/mot/deepsort/deepsort_faster-rcnn_fpn_4e_mot17-private-half.py')

cfg.model.detector.init_cfg.checkpoint = '/content/drive/Othercomputers/내 노트북/google_drive/DeepSORT_ReID_result/epoch_15.pth'
cfg.model.reid.init_cfg.checkpoint = '/content/drive/Othercomputers/내 노트북/google_drive/DeepSORT_ReID_result/only_ReID/epoch_5.pth'

cfg.work_dir = '/content/drive/Othercomputers/내 노트북/google_drive/total_DeepSORT_result'
cfg.seed = 0
set_random_seed(0, deterministic=False)
cfg.gpu_ids = range(1)
cfg.data.test.test_mode = True
cfg.device='cuda'

print(cfg)
# Out:
# Config (path: ./configs/mot/deepsort/deepsort_faster-rcnn_fpn_4e_mot17-private-half.py): {'model': {'detector': {'type': 'FasterRCNN', 'backbone': {'type': 'ResNet', 'depth': 50, 'num_stages': 4, 'out_indices': (0, 1, 2, 3), 'frozen_stages': 1, 'norm_cfg': {'type': 'BN', 'requires_grad': True}, 'norm_eval': True, 'style': 'pytorch', 'init_cfg': {'type': 'Pretrained', 'checkpoint': 'torchvision://resnet50'}}, 'neck': {'type': 'FPN', 'in_channels': [256, 512, 1024, 2048], 'out_channels': 256, 'num_outs': 5}, 'rpn_head': {'type': 'RPNHead', 'in_channels': 256, 'feat_channels': 256, 'anchor_generator': {'type': 'AnchorGenerator', 'scales': [8], 'ratios': [0.5, 1.0, 2.0], 'strides': [4, 8, 16, 32, 64]}, 'bbox_coder': {'type': 'DeltaXYWHBBoxCoder', 'target_means': [0.0, 0.0, 0.0, 0.0], 'target_stds': [1.0, 1.0, 1.0, 1.0], 'clip_border': False}, 'loss_cls': {'type': 'CrossEntropyLoss', 'use_sigmoid': True, 'loss_weight': 1.0}, 'loss_bbox': {'type': 'SmoothL1Loss', 'beta': 0.1111111111111111
# ...

# %%
cfg.model.detector.init_cfg.checkpoint
# Out:
# '/content/drive/Othercomputers/내 노트북/google_drive/DeepSORT_ReID_result/epoch_15.pth'

# %%
cfg.model.reid.init_cfg.checkpoint
# Out:
# '/content/drive/Othercomputers/내 노트북/google_drive/DeepSORT_ReID_result/only_ReID/epoch_5.pth'

# %%
cfg.data.train
# Out:
# {'type': 'MOTChallengeDataset',
#  'visibility_thr': -1,
#  'ann_file': 'data/MOT17_tiny/annotations/train_cocoformat.json',
#  'img_prefix': 'data/MOT17_tiny/train',
#  'ref_img_sampler': {'num_ref_imgs': 1,
#   'frame_range': 10,
#   'filter_key_img': True,
#   'method': 'uniform'},
#  'classes': ('pedestrian',),
#  'pipeline': [{'type': 'LoadMultiImagesFromFile', 'to_float32': True},
#   {'type': 'SeqLoadAnnotations', 'with_bbox': True, 'with_track': True},
#   {'type': 'SeqResize',
#    'img_scale': (1088, 1088),
#    'share_params': True,
#    'ratio_range': (0.8, 1.2),
#    'keep_ratio': True,
#    'bbox_clip_border': False},
#   {'type': 'SeqPhotoMetricDistortion', 'share_params': True},
#   {'type': 'SeqRandomCrop',
#    'share_params': False,
#    'crop_size': (1088, 1088),
#    'bbox_clip_border': False},
#   {'type': 'SeqRandomFlip', 'share_params': True, 'flip_ratio': 0.5},
#   {'type': 'SeqNormalize',
#    'mean': [123.675, 116.28, 103.53],
# ...

# %%
cfg.data.test
# Out:
# {'type': 'MOTChallengeDataset',
#  'ann_file': 'data/MOT17_tiny/annotations/half-val_cocoformat.json',
#  'img_prefix': 'data/MOT17_tiny/train',
#  'ref_img_sampler': None,
#  'classes': ('pedestrian',),
#  'pipeline': [{'type': 'LoadImageFromFile'},
#   {'type': 'MultiScaleFlipAug',
#    'img_scale': (1088, 1088),
#    'flip': False,
#    'transforms': [{'type': 'Resize', 'keep_ratio': True},
#     {'type': 'RandomFlip'},
#     {'type': 'Normalize',
#      'mean': [123.675, 116.28, 103.53],
#      'std': [58.395, 57.12, 57.375],
#      'to_rgb': True},
#     {'type': 'Pad', 'size_divisor': 32},
#     {'type': 'ImageToTensor', 'keys': ['img']},
#     {'type': 'VideoCollect', 'keys': ['img']}]}],
#  'test_mode': True}

# %%
from mmtrack.datasets import build_dataloader
from mmtrack.apis import init_model
from mmcv.parallel import MMDataParallel
from mmtrack.apis import single_gpu_test
from mmtrack.datasets import build_dataset

dataset = build_dataset(cfg.data.test)
data_loader = build_dataloader(
    dataset,
    samples_per_gpu=1,
    workers_per_gpu=cfg.data.workers_per_gpu,
    dist=False,
    shuffle=False)
# Out:
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!

# %%
dataset
# Out:
# MOTChallengeDataset Test dataset with number of images 87, and instance counts:
# +----------------+-------+----------+-------+----------+-------+----------+-------+----------+-------+
# | category       | count | category | count | category | count | category | count | category | count |
# +----------------+-------+----------+-------+----------+-------+----------+-------+----------+-------+
# |                |       |          |       |          |       |          |       |          |       |
# | 0 [pedestrian] | 696   |          |       |          |       |          |       |          |       |
# +----------------+-------+----------+-------+----------+-------+----------+-------+----------+-------+

# %%
dataset.CLASSES
# Out:
# ('pedestrian',)

# %%
# !pwd
# Out:
# /content/mmtracking

# %%
# 1분 소모

# build the model and load checkpoint
model = init_model(cfg)

model = MMDataParallel(model, device_ids=cfg.gpu_ids)
model.CLASSES = dataset.CLASSES
outputs = single_gpu_test(model, data_loader)
# Out:
# 2024-04-16 14:14:47,323 - mmcv - INFO - initialize FasterRCNN with init_cfg {'type': 'Pretrained', 'checkpoint': '/content/drive/Othercomputers/내 노트북/google_drive/DeepSORT_ReID_result/epoch_15.pth'}
# 2024-04-16 14:14:47,325 - mmcv - INFO - load model from: /content/drive/Othercomputers/내 노트북/google_drive/DeepSORT_ReID_result/epoch_15.pth
# 2024-04-16 14:14:47,326 - mmcv - INFO - load checkpoint from local path: /content/drive/Othercomputers/내 노트북/google_drive/DeepSORT_ReID_result/epoch_15.pth
# 2024-04-16 14:14:47,810 - mmcv - INFO - initialize BaseReID with init_cfg {'type': 'Pretrained', 'checkpoint': '/content/drive/Othercomputers/내 노트북/google_drive/DeepSORT_ReID_result/only_ReID/epoch_5.pth'}
# 2024-04-16 14:14:47,811 - mmcv - INFO - load model from: /content/drive/Othercomputers/내 노트북/google_drive/DeepSORT_ReID_result/only_ReID/epoch_5.pth
# ...

# %%
eval_kwargs = cfg.get('evaluation', {}).copy()
# hard-code way to remove EvalHook args
eval_hook_args = [
    'interval', 'tmpdir', 'start', 'gpu_collect', 'save_best',
    'rule', 'by_epoch'
]
for key in eval_hook_args:
    eval_kwargs.pop(key, None)
eval_kwargs.update(dict(metric=['track']))
metric = dataset.evaluate(outputs, **eval_kwargs)

print(metric)
# Out:
# Evaluate CLEAR MOT results.
#
# Eval Config:
# USE_PARALLEL         : False
# NUM_PARALLEL_CORES   : 8
# BREAK_ON_ERROR       : True
# RETURN_ON_ERROR      : False
# LOG_ON_ERROR         : /usr/local/lib/python3.10/dist-packages/error_log.txt
# PRINT_RESULTS        : True
# PRINT_ONLY_COMBINED  : False
# PRINT_CONFIG         : True
# TIME_PROGRESS        : True
# DISPLAY_LESS_PROGRESS : True
# OUTPUT_SUMMARY       : True
# OUTPUT_EMPTY_CLASSES : True
# OUTPUT_DETAILED      : True
# PLOT_CURVES          : True
#
# MotChallenge2DBox Config:
# GT_FOLDER            : /tmp/tmpkeeve30d
# TRACKERS_FOLDER      : /tmp/tmpz13ibzoz
# OUTPUT_FOLDER        : None
# TRACKERS_TO_EVAL     : ['track']
# CLASSES_TO_EVAL      : ['pedestrian']
# BENCHMARK            : MOT17
# SPLIT_TO_EVAL        : train
# INPUT_AS_ZIP         : False
# PRINT_CONFIG         : True
# DO_PREPROC           : True
# TRACKER_SUB_FOLDER   :
# OUTPUT_SUB_FOLDER    :
# TRACKER_DISPLAY_NAMES : None
# SEQMAP_FOLDER        : None
# ...

# %%
# ///=== Run MOT(Multi Object Tracking) Inference ===///

import mmcv
import tempfile # 임시 파일과 디렉터리를 만드는 모듈.

from mmtrack.apis import inference_mot, init_model

input_video = '/content/drive/Othercomputers/내 노트북/google_drive/DeepSORT_ReID_input/real_real_DeepSORT_input.mp4'
imgs = mmcv.VideoReader(input_video)

# build the model from a config file
mot_model = init_model(cfg, device='cuda:0')
# mot_model.CLASSES = dataset.CLASSES

prog_bar = mmcv.ProgressBar(len(imgs))
out_dir = tempfile.TemporaryDirectory()
out_path = out_dir.name

# test and show/save the images(inference)
for i, img in enumerate(imgs):
    result = inference_mot(mot_model, img, frame_id=i)
    mot_model.show_result(
            img,
            result,
            show=False,
            wait_time=int(1000. / imgs.fps),
            out_file=f'{out_path}/{i:06d}.jpg')
    prog_bar.update()

output = '/content/drive/Othercomputers/내 노트북/google_drive/total_DeepSORT_result/mot_out.mp4'
print(f'\n making the output video at {output} with a FPS of {imgs.fps}')
mmcv.frames2video(out_path, output, fps=imgs.fps, fourcc='mp4v')
out_dir.cleanup()
# Out:
# 2024-04-17 06:23:22,728 - mmcv - INFO - initialize FasterRCNN with init_cfg {'type': 'Pretrained', 'checkpoint': '/content/drive/Othercomputers/내 노트북/google_drive/DeepSORT_ReID_result/epoch_15.pth'}
# 2024-04-17 06:23:22,729 - mmcv - INFO - load model from: /content/drive/Othercomputers/내 노트북/google_drive/DeepSORT_ReID_result/epoch_15.pth
# 2024-04-17 06:23:22,731 - mmcv - INFO - load checkpoint from local path: /content/drive/Othercomputers/내 노트북/google_drive/DeepSORT_ReID_result/epoch_15.pth
# 2024-04-17 06:23:23,166 - mmcv - INFO - initialize BaseReID with init_cfg {'type': 'Pretrained', 'checkpoint': '/content/drive/Othercomputers/내 노트북/google_drive/DeepSORT_ReID_result/only_ReID/epoch_5.pth'}
# 2024-04-17 06:23:23,168 - mmcv - INFO - load model from: /content/drive/Othercomputers/내 노트북/google_drive/DeepSORT_ReID_result/only_ReID/epoch_5.pth
# ...

# %% [markdown]
# # DeepSORT without ReID

# %%
import mmcv
from mmdet.apis import set_random_seed

# /content/mmtracking/configs/mot/deepsort/deepsort_faster-rcnn_fpn_4e_mot17-private-half.py
cfg = mmcv.Config.fromfile('./configs/mot/deepsort/deepsort_faster-rcnn_fpn_4e_mot17-private-half.py')

cfg.model.detector.init_cfg.checkpoint = '/content/drive/Othercomputers/내 노트북/google_drive/DeepSORT_ReID_result/epoch_10.pth'
# cfg.model.reid.init_cfg.checkpoint = '/content/drive/Othercomputers/내 노트북/google_drive/DeepSORT_ReID_result/only_ReID/epoch_15.pth'

cfg.work_dir = '/content/drive/Othercomputers/내 노트북/google_drive/total_DeepSORT_result/without_ReID'
cfg.seed = 0
set_random_seed(0, deterministic=False)
cfg.gpu_ids = range(1)
cfg.data.test.test_mode = True
cfg.device='cuda'

print(cfg)
# Out:
# Config (path: ./configs/mot/deepsort/deepsort_faster-rcnn_fpn_4e_mot17-private-half.py): {'model': {'detector': {'type': 'FasterRCNN', 'backbone': {'type': 'ResNet', 'depth': 50, 'num_stages': 4, 'out_indices': (0, 1, 2, 3), 'frozen_stages': 1, 'norm_cfg': {'type': 'BN', 'requires_grad': True}, 'norm_eval': True, 'style': 'pytorch', 'init_cfg': {'type': 'Pretrained', 'checkpoint': 'torchvision://resnet50'}}, 'neck': {'type': 'FPN', 'in_channels': [256, 512, 1024, 2048], 'out_channels': 256, 'num_outs': 5}, 'rpn_head': {'type': 'RPNHead', 'in_channels': 256, 'feat_channels': 256, 'anchor_generator': {'type': 'AnchorGenerator', 'scales': [8], 'ratios': [0.5, 1.0, 2.0], 'strides': [4, 8, 16, 32, 64]}, 'bbox_coder': {'type': 'DeltaXYWHBBoxCoder', 'target_means': [0.0, 0.0, 0.0, 0.0], 'target_stds': [1.0, 1.0, 1.0, 1.0], 'clip_border': False}, 'loss_cls': {'type': 'CrossEntropyLoss', 'use_sigmoid': True, 'loss_weight': 1.0}, 'loss_bbox': {'type': 'SmoothL1Loss', 'beta': 0.1111111111111111
# ...

# %%
cfg.model.reid.init_cfg.checkpoint
# Out:
# 'https://download.openmmlab.com/mmtracking/mot/reid/tracktor_reid_r50_iter25245-a452f51f.pth'

# %%
from mmtrack.datasets import build_dataloader
from mmtrack.apis import init_model
from mmcv.parallel import MMDataParallel
from mmtrack.apis import single_gpu_test
from mmtrack.datasets import build_dataset

dataset = build_dataset(cfg.data.test)
data_loader = build_dataloader(
    dataset,
    samples_per_gpu=1,
    workers_per_gpu=cfg.data.workers_per_gpu,
    dist=False,
    shuffle=False)
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!

# %%
dataset
# Out:
# MOTChallengeDataset Test dataset with number of images 87, and instance counts:
# +----------------+-------+----------+-------+----------+-------+----------+-------+----------+-------+
# | category       | count | category | count | category | count | category | count | category | count |
# +----------------+-------+----------+-------+----------+-------+----------+-------+----------+-------+
# |                |       |          |       |          |       |          |       |          |       |
# | 0 [pedestrian] | 696   |          |       |          |       |          |       |          |       |
# +----------------+-------+----------+-------+----------+-------+----------+-------+----------+-------+

# %%
# 1분 소모

# build the model and load checkpoint
model = init_model(cfg)

model = MMDataParallel(model, device_ids=cfg.gpu_ids)
model.CLASSES = dataset.CLASSES
outputs = single_gpu_test(model, data_loader)
# Out:
# 2024-04-16 14:15:58,818 - mmcv - INFO - initialize FasterRCNN with init_cfg {'type': 'Pretrained', 'checkpoint': '/content/drive/Othercomputers/내 노트북/google_drive/DeepSORT_ReID_result/epoch_10.pth'}
# 2024-04-16 14:15:58,819 - mmcv - INFO - load model from: /content/drive/Othercomputers/내 노트북/google_drive/DeepSORT_ReID_result/epoch_10.pth
# 2024-04-16 14:15:58,820 - mmcv - INFO - load checkpoint from local path: /content/drive/Othercomputers/내 노트북/google_drive/DeepSORT_ReID_result/epoch_10.pth
# 2024-04-16 14:15:59,245 - mmcv - INFO - initialize BaseReID with init_cfg {'type': 'Pretrained', 'checkpoint': 'https://download.openmmlab.com/mmtracking/mot/reid/tracktor_reid_r50_iter25245-a452f51f.pth'}
# 2024-04-16 14:15:59,246 - mmcv - INFO - load model from: https://download.openmmlab.com/mmtracking/mot/reid/tracktor_reid_r50_iter25245-a452f51f.pth
# ...

# %%
eval_kwargs = cfg.get('evaluation', {}).copy()
# hard-code way to remove EvalHook args
eval_hook_args = [
    'interval', 'tmpdir', 'start', 'gpu_collect', 'save_best',
    'rule', 'by_epoch'
]
for key in eval_hook_args:
    eval_kwargs.pop(key, None)
eval_kwargs.update(dict(metric=['track']))
metric = dataset.evaluate(outputs, **eval_kwargs)

print(metric)
# Out:
# Evaluate CLEAR MOT results.
#
# Eval Config:
# USE_PARALLEL         : False
# NUM_PARALLEL_CORES   : 8
# BREAK_ON_ERROR       : True
# RETURN_ON_ERROR      : False
# LOG_ON_ERROR         : /usr/local/lib/python3.10/dist-packages/error_log.txt
# PRINT_RESULTS        : True
# PRINT_ONLY_COMBINED  : False
# PRINT_CONFIG         : True
# TIME_PROGRESS        : True
# DISPLAY_LESS_PROGRESS : True
# OUTPUT_SUMMARY       : True
# OUTPUT_EMPTY_CLASSES : True
# OUTPUT_DETAILED      : True
# PLOT_CURVES          : True
#
# MotChallenge2DBox Config:
# GT_FOLDER            : /tmp/tmpqnyggiz9
# TRACKERS_FOLDER      : /tmp/tmpvn1p6_zf
# OUTPUT_FOLDER        : None
# TRACKERS_TO_EVAL     : ['track']
# CLASSES_TO_EVAL      : ['pedestrian']
# BENCHMARK            : MOT17
# SPLIT_TO_EVAL        : train
# INPUT_AS_ZIP         : False
# PRINT_CONFIG         : True
# DO_PREPROC           : True
# TRACKER_SUB_FOLDER   :
# OUTPUT_SUB_FOLDER    :
# TRACKER_DISPLAY_NAMES : None
# SEQMAP_FOLDER        : None
# ...
